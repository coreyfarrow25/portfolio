# %%
import numpy as np

X = np.array([100, 500, 1000, 0, 10000, 0, 1000, 500, 100])

P_A = np.array([0.226, 0.387, 0.242, 0.107, 0.032, 0.006, 0,     0,     0    ])
P_B = np.array([0.193, 0.347, 0.247, 0.137, 0.057, 0.016, 0.003, 0,     0    ])
P_C = np.array([0.121, 0.247, 0.241, 0.196, 0.121, 0.054, 0.017, 0.003, 0    ])
P_D = np.array([0.054, 0.137, 0.196, 0.226, 0.193, 0.121, 0.054, 0.016, 0.003])
P_E = np.array([0.016, 0.057, 0.121, 0.193, 0.226, 0.193, 0.121, 0.057, 0.016])
P_F = np.array([0.003, 0.016, 0.054, 0.121, 0.193, 0.226, 0.196, 0.137, 0.054])
P_G = np.array([0,     0.003, 0.017, 0.054, 0.121, 0.196, 0.241, 0.247, 0.121])
P_H = np.array([0,     0,     0.003, 0.016, 0.057, 0.137, 0.247, 0.347, 0.193])
P_I = np.array([0,     0,     0,     0.006, 0.032, 0.107, 0.242, 0.387, 0.226])

for loc, p in zip('ABCDEFGHI', [P_A,P_B,P_C,P_D,P_E,P_F,P_G,P_H,P_I]):
    mu = np.sum(X * p)
    sigma = np.sqrt(np.sum((X - mu)**2 * p))
    print(f"Expected winnings starting at location {loc} is ${mu:.2f}")
    print(f"Standard deviation of winnings starting at location {loc} is ${sigma:.2f}")
# Out:
# Expected winnings starting at location A is $778.10
# Standard deviation of winnings starting at location A is $1713.35
# Expected winnings starting at location B is $1012.80
# Standard deviation of winnings starting at location B is $2238.95
# Expected winnings starting at location C is $1605.10
# Standard deviation of winnings starting at location C is $3137.73
# Expected winnings starting at location D is $2262.20
# Standard deviation of winnings starting at location D is $3804.11
# Expected winnings starting at location E is $2562.20
# Standard deviation of winnings starting at location E is $4038.06
# Expected winnings starting at location F is $2262.20
# Standard deviation of winnings starting at location F is $3804.11
# Expected winnings starting at location G is $1605.10
# Standard deviation of winnings starting at location G is $3137.73
# Expected winnings starting at location H is $1012.80
# Standard deviation of winnings starting at location H is $2238.95
# Expected winnings starting at location I is $778.10
# Standard deviation of winnings starting at location I is $1713.35
